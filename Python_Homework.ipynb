# %% [markdown]
# # Homework: Python Functions & Data Processing
# ## CSC 2053 - Homework 6 - Fall 2025
#
# **Student Name:** [Your Name Here]
#
# **Due Date:** [Insert Date]
#
# **Sources/Collaborators:** [List any online sources, TAs, or classmates who helped]
#
# ---
#
# ## Instructions
#
# Complete all five functions in this notebook as specified in the docstrings. Each function has test cases that will print "✓ Correct" when your implementation is working.
#
# **Grading:**
# - Part 1 Functions (5 functions): 70 points
# - Part 2 Custom Functions: 20 points
# - Code Quality (comments, readability): 10 points
#
# **Submission:**
# 1. Complete all functions
# 2. Run all cells to verify tests pass
# 3. Upload this notebook to your GitHub repository
# 4. Submit GitHub repository link on Blackboard

# %% [markdown]
# ---
# ## Part 1: Required Functions (70 points)
#
# ### Function 1: Villanova Chant (14 points)
#
# Create a function that generates a proper Villanova chant!

# %%
def nova_chant(phrase, times):
    """
    Given a phrase and number of times, return the phrase repeated that many times
    with "Go Nova!" appended at the end.
    
    Examples:
        nova_chant("V-U!", 3) → "V-U! V-U! V-U! Go Nova!"
        nova_chant("Wildcats!", 2) → "Wildcats! Wildcats! Go Nova!"
    
    Parameters:
        phrase (str): The phrase to repeat
        times (int): Number of times to repeat the phrase
    
    Returns:
        str: The chant with "Go Nova!" at the end
    """
    # YOUR CODE HERE
    pass

# %%
# Test cases for nova_chant
assert nova_chant("V-U!", 3) == "V-U! V-U! V-U! Go Nova!", "Test 1 failed"
print("✓ Test 1 passed")

assert nova_chant("Wildcats!", 2) == "Wildcats! Wildcats! Go Nova!", "Test 2 failed"
print("✓ Test 2 passed")

assert nova_chant("Defense!", 4) == "Defense! Defense! Defense! Defense! Go Nova!", "Test 3 failed"
print("✓ Test 3 passed")

# %% [markdown]
# ### Function 2: Eagles Score Checker (14 points)
#
# Given a list of game scores, check if the Eagles scored a touchdown (7 points) followed by a field goal (3 points) in consecutive scores.

# %%
def touchdown_fieldgoal(scores):
    """
    Return True if the list contains a 7 followed immediately by a 3.
    This represents a touchdown (7 points) followed by a field goal (3 points).
    
    Examples:
        touchdown_fieldgoal([7, 3, 7]) → True
        touchdown_fieldgoal([7, 7, 3]) → False
        touchdown_fieldgoal([3, 7, 3, 7]) → False
    
    Parameters:
        scores (list): List of integers representing points scored
    
    Returns:
        bool: True if 7 is followed by 3, False otherwise
    """
    # YOUR CODE HERE
    pass

# %%
# Test cases for touchdown_fieldgoal
assert touchdown_fieldgoal([7, 3, 7]) is True, "Test 1 failed"
print("✓ Test 1 passed")

assert touchdown_fieldgoal([7, 7, 3]) is False, "Test 2 failed"
print("✓ Test 2 passed")

assert touchdown_fieldgoal([3, 7, 3, 7, 3]) is True, "Test 3 failed"
print("✓ Test 3 passed")

# %% [markdown]
# ### Function 3: Kenny G Song Finder (14 points)
#
# Find songs in a string that match a pattern! We'll look for words that start with 's' and end with 'g' (like "song").

# %%
def count_smooth_songs(text):
    """
    Count how many times a 4-letter word appears that starts with 's' and ends with 'g',
    with any two letters in between. For example: "song", "sing", "smog" all count.
    
    Examples:
        count_smooth_songs("song and sing") → 2
        count_smooth_songs("smog song strong") → 2  # strong is 6 letters, doesn't count
        count_smooth_songs("snog and shag") → 2
    
    Parameters:
        text (str): The text to search
    
    Returns:
        int: Count of matching 4-letter words
    
    Hint: You can use string slicing and a loop, or explore the 're' module for pattern matching!
    """
    # YOUR CODE HERE
    pass

# %%
# Test cases for count_smooth_songs
assert count_smooth_songs("song and sing") == 2, "Test 1 failed"
print("✓ Test 1 passed")

assert count_smooth_songs("smog song strong") == 2, "Test 2 failed"
print("✓ Test 2 passed")

assert count_smooth_songs("sxng and syyg") == 2, "Test 3 failed"
print("✓ Test 3 passed")

# %% [markdown]
# ### Function 4: RadioLand Station Counter (14 points)
#
# Given a text containing callsigns and frequencies, count how many FM and AM stations appear.
# FM frequencies are 88.0-108.0, AM frequencies are 530-1700.

# %%
def count_fm_am(station_data):
    """
    Given a dictionary with station callsigns as keys and frequencies as values,
    return a dictionary with counts: {"FM": count, "AM": count}
    
    FM stations: 88.0 - 108.0 MHz
    AM stations: 530 - 1700 kHz
    
    Examples:
        count_fm_am({"WXPN": 88.5, "KYW": 1060, "WMMR": 93.3})
        → {"FM": 2, "AM": 1}
    
    Parameters:
        station_data (dict): Dictionary of {callsign: frequency}
    
    Returns:
        dict: {"FM": count, "AM": count}
    """
    # YOUR CODE HERE
    pass

# %%
# Test cases for count_fm_am
result1 = count_fm_am({"WXPN": 88.5, "KYW": 1060, "WMMR": 93.3})
assert result1 == {"FM": 2, "AM": 1}, "Test 1 failed"
print("✓ Test 1 passed")

result2 = count_fm_am({"WFIL": 560, "WDAS": 1480, "WOGL": 98.1})
assert result2 == {"FM": 1, "AM": 2}, "Test 2 failed"
print("✓ Test 2 passed")

result3 = count_fm_am({"WYSP": 94.1, "WIOQ": 102.1, "WUSL": 98.9})
assert result3 == {"FM": 3, "AM": 0}, "Test 3 failed"
print("✓ Test 3 passed")

# %% [markdown]
# ### Function 5: Basketball Stats Average (14 points)
#
# Calculate the "game average" for Villanova basketball - but ignore the highest and lowest scoring games.

# %%
def game_average(scores):
    """
    Return the average of the scores, ignoring the highest and lowest values.
    If there are multiple copies of the lowest or highest, only ignore one copy.
    Use floor division (//) for the final average.
    Assume the list has at least 3 elements.
    
    Examples:
        game_average([70, 85, 90, 78, 95]) → 84  # ignore 70 and 95, avg of 85,90,78
        game_average([60, 60, 70, 80, 90]) → 70  # ignore one 60 and 90
    
    Parameters:
        scores (list): List of integer scores
    
    Returns:
        int: Floor division average ignoring min and max
    """
    # YOUR CODE HERE
    pass

# %%
# Test cases for game_average
assert game_average([70, 85, 90, 78, 95]) == 84, "Test 1 failed"
print("✓ Test 1 passed")

assert game_average([60, 60, 70, 80, 90]) == 70, "Test 2 failed"
print("✓ Test 2 passed")

assert game_average([50, 60, 70, 80, 90, 100]) == 75, "Test 3 failed"
print("✓ Test 3 passed")

# %% [markdown]
# ---
# ## Part 2: Custom Functions (20 points)
#
# Create two original functions with the following requirements:
#
# ### Custom Function 1 (10 points)
# Write a function that:
# - Takes a **list** as a parameter
# - Returns an **integer**
# - Has a clear purpose (describe in comments)
# - Include 3 test calls demonstrating your function

# %%
def my_list_function(input_list):
    """
    [DESCRIBE WHAT YOUR FUNCTION DOES]
    
    Parameters:
        input_list (list): [describe the parameter]
    
    Returns:
        int: [describe what you return]
    """
    # YOUR CODE HERE
    pass

# Test calls (3 different examples)
print("Test 1:", my_list_function([]))  # Add your test data
print("Test 2:", my_list_function([]))  # Add your test data
print("Test 3:", my_list_function([]))  # Add your test data

# %% [markdown]
# ### Custom Function 2 (10 points)
# Write a function that:
# - Takes **any number of parameters** (your choice)
# - Returns **any type** (your choice)
# - Serves a clear purpose (describe in comments)
# - Include 3 test calls demonstrating your function

# %%
def my_creative_function():
    """
    [DESCRIBE WHAT YOUR FUNCTION DOES]
    
    Parameters:
        [list your parameters and their types]
    
    Returns:
        [type]: [describe what you return]
    """
    # YOUR CODE HERE
    pass

# Test calls (3 different examples)
print("Test 1:", my_creative_function())  # Add your test data
print("Test 2:", my_creative_function())  # Add your test data
print("Test 3:", my_creative_function())  # Add your test data

# %% [markdown]
# ---
# ## Submission Checklist
#
# Before submitting, make sure:
#
# - [ ] Your name is at the top of the notebook
# - [ ] All functions are implemented (not just `pass`)
# - [ ] All test cases pass (show "✓ Correct")
# - [ ] Code is properly commented
# - [ ] Custom functions have 3 test calls each
# - [ ] You've cited any sources or collaborators
# - [ ] Notebook runs from top to bottom without errors
#
# **To Submit:**
# 1. Save this notebook
# 2. Upload to your GitHub repository
# 3. Submit the GitHub repository link on Blackboard
#
# ---
#
# ## Notes
#
# **Code Quality Matters!**
# - Use meaningful variable names
# - Add comments explaining your logic
# - Keep functions focused and readable
#
# Good luck! 🎷🏀🦅
